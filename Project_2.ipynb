# %% [markdown]
# Research Question: What borough would have the highest math score between Manhattan and the Bronx? (Common Core Algebra)
# P.S.184 Shuang Wen is in Manhattan and Icahn Charter School is in the Bronx.

# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
import pandas as pd

# %%
import seaborn as sns

# %%
# %matplotlib inline

# %%
missing_values = ["S", "na", "s", "--"]

# %%
df = pd.read_csv("https://raw.githubusercontent.com/CunyLaguardiaDataAnalytics/datasets/master/2014-15_To_2016-17_School-_Level_NYC_Regents_Report_For_All_Variables.csv", na_values = missing_values)

# %%
df.head(25)
# Out:
#    School DBN  ... Percent Scoring CR
# 0      01M034  ...                NaN
# 1      01M034  ...                NaN
# 2      01M034  ...                NaN
# 3      01M140  ...                NaN
# 4      01M140  ...                NaN
# 5      01M140  ...                NaN
# 6      01M140  ...                NaN
# 7      01M140  ...                NaN
# 8      01M184  ...               98.0
# 9      01M184  ...               78.4
# 10     01M184  ...               98.0
# 11     01M184  ...                NaN
# 12     01M188  ...                8.7
# 13     01M188  ...               68.2
# 14     01M188  ...               50.0
# 15     01M188  ...                NaN
# 16     01M188  ...                NaN
# 17     01M188  ...                NaN
# 18     01M292  ...                NaN
# 19     01M292  ...                NaN
# 20     01M292  ...                0.0
# 21     01M292  ...               30.0
# 22     01M292  ...               54.7
# 23     01M292  ...                0.0
# ...

# %%
df.shape
# Out:
# (212331, 15)

# %%
df.tail(25)
# Out:
#        School DBN  ... Percent Scoring CR
# 212306     84X705  ...                NaN
# 212307     84X705  ...                NaN
# 212308     84X706  ...                NaN
# 212309     84X706  ...                NaN
# 212310     84X706  ...                NaN
# 212311     84X706  ...              100.0
# 212312     84X706  ...                NaN
# 212313     84X706  ...                NaN
# 212314     84X706  ...                NaN
# 212315     84X706  ...                NaN
# 212316     84X706  ...                NaN
# 212317     84X706  ...                NaN
# 212318     84X717  ...                NaN
# 212319     84X717  ...                NaN
# 212320     84X717  ...              100.0
# 212321     84X717  ...              100.0
# 212322     84X717  ...              100.0
# 212323     84X717  ...              100.0
# 212324     84X717  ...                NaN
# 212325     84X717  ...                NaN
# 212326     84X717  ...                NaN
# ...

# %%
df.columns
# Out:
# Index(['School DBN', 'School Name', 'School Level', 'Regents Exam', 'Year',
#        'Total Tested', 'Mean Score', 'Number Scoring Below 65',
#        'Percent Scoring Below 65', 'Number Scoring 65 or Above',
#        'Percent Scoring 65 or Above', 'Number Scoring 80 or Above',
#        'Percent Scoring 80 or Above', 'Number Scoring CR',
#        'Percent Scoring CR'],
#       dtype='object')

# %%
df2 = df[['School Name','Regents Exam','School Level', 'Year', 'Percent Scoring 65 or Above', 'Total Tested']]

# %%
df['School Level'].unique()
# Out:
# array(['K-8', 'High school', 'Junior High-Intermediate-Middle',
#        'Secondary School', 'K-12 all grades', 'Elementary'], dtype=object)

# %%
df2
# Out:
#                            School Name  ... Total Tested
# 0       P.S. 034 Franklin D. Roosevelt  ...            4
# 1       P.S. 034 Franklin D. Roosevelt  ...           16
# 2       P.S. 034 Franklin D. Roosevelt  ...            9
# 3               P.S. 140 Nathan Straus  ...            3
# 4               P.S. 140 Nathan Straus  ...            2
# ...                                ...  ...          ...
# 212326            Icahn Charter School  ...            8
# 212327            Icahn Charter School  ...            5
# 212328            Icahn Charter School  ...            6
# 212329            Icahn Charter School  ...            4
# 212330            Icahn Charter School  ...            1
#
# [212331 rows x 6 columns]

# %%
df2.groupby(['School Level']).count()
# Out:
#                                  School Name  ...  Total Tested
# School Level                                  ...
# Elementary                                25  ...            25
# High school                           151160  ...        151160
# Junior High-Intermediate-Middle        15742  ...         15742
# K-12 all grades                         8294  ...          8294
# K-8                                     6858  ...          6858
# Secondary School                       30252  ...         30252
#
# [6 rows x 5 columns]

# %%
df3['Regents Exam'].unique()
# Out:
# array(['Common Core Algebra', 'Living Environment', 'Common Core English',
#        'Physical Settings/Earth Science', 'U.S. History and Government',
#        'Common Core Geometry', 'Integrated Algebra', 'English',
#        'Global History and Geography', 'Algebra2/Trigonometry',
#        'Common Core Algebra2', 'Geometry', 'Physical Settings/Chemistry'],
#       dtype=object)

# %%
df3=df2[df2['School Level'].str.contains('K-8')]

# %%
schoolselected= df3[df3['Regents Exam']=='Common Core Algebra']

# %%
schoolselected
# Out:
#                            School Name  ... Total Tested
# 0       P.S. 034 Franklin D. Roosevelt  ...            4
# 3               P.S. 140 Nathan Straus  ...            3
# 4               P.S. 140 Nathan Straus  ...            2
# 8                 P.S. 184m Shuang Wen  ...           49
# 9                 P.S. 184m Shuang Wen  ...           51
# ...                                ...  ...          ...
# 212319            Icahn Charter School  ...            2
# 212320            Icahn Charter School  ...            8
# 212321            Icahn Charter School  ...            6
# 212322            Icahn Charter School  ...            6
# 212323            Icahn Charter School  ...            6
#
# [3211 rows x 6 columns]

# %%
schoolselected[(schoolselected['School Name']=='Icahn Charter School') | (schoolselected['School Name']=='P.S. 184m Shuang Wen')].head(15)
# Out:
#                 School Name  ... Total Tested
# 8      P.S. 184m Shuang Wen  ...           49
# 9      P.S. 184m Shuang Wen  ...           51
# 10     P.S. 184m Shuang Wen  ...           51
# 19471  Icahn Charter School  ...            7
# 19472  Icahn Charter School  ...           14
# 19473  Icahn Charter School  ...           12
# 19489  P.S. 184m Shuang Wen  ...           47
# 19490  P.S. 184m Shuang Wen  ...            2
# 19491  P.S. 184m Shuang Wen  ...           46
# 19492  P.S. 184m Shuang Wen  ...            5
# 19493  P.S. 184m Shuang Wen  ...           50
# 19494  P.S. 184m Shuang Wen  ...            1
# 54226  Icahn Charter School  ...            6
# 54227  Icahn Charter School  ...            1
# 54228  Icahn Charter School  ...           14
#
# [15 rows x 6 columns]

# %%
schoolselected.groupby(['Year']).count()
# Out:
#       School Name  Regents Exam  ...  Number Scoring 65 or Above  Total Tested
# Year                             ...
# 2015          945           945  ...                         442           945
# 2016         1009          1009  ...                         481          1009
# 2017         1257          1257  ...                         599          1257
#
# [3 rows x 5 columns]

# %%
schoolselected.plot(kind='hist', x='School Name', y= 'Number Scoring 65 or Above', title= 'NYC Regents Exam');

# %%
schoolselected.groupby(['School Name']).count().plot(kind='hist')

# %%
Conclusion: The school in Manhattan(P.S. 184m) had the higher math score (Common Core Algebra) as compared to the Bronx (Icahn Charter School)
